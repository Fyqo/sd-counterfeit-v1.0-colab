# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %pip install -q https://github.com/Fyqo/xformers-wheels/releases/download/xformers/xformers-0.0.15.dev0+4c06c79.d20221205-cp38-cp38-linux_x86_64.whl
# !curl -Lo counterfeit-v1.0.ckpt https://huggingface.co/gsdf/counterfeit-v1.0/resolve/main/counterfeit-v1.0.ckpt
# !mv "/content/counterfeit-v1.0.ckpt" "/content/stable-diffusion-webui/models/Stable-diffusion"
# %cd /content/stable-diffusion-webui
# !COMMANDLINE_ARGS="--share --gradio-debug --medvram --disable-safe-unpickle --force-enable-xformers" REQS_FILE="requirements.txt" python launch.py

# %% [markdown]
# # 📚 GitHub for more: [_@Fyqo_](https://github.com/Fyqo)
# # 📦 Repo: [Github](https://github.com/Fyqo/sd-counterfeit-v1.0-colab)
